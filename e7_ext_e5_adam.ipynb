# %% [markdown]
# # e5_ext_e4_less_lr
#
# This is the baseline experiment. It includes following components in the model:
# * 64x64x3 input size
# * Data Augmentations
# * 8 Convolutional Layers
# * Pooling Layer after skipping 1 convolutional Layer each
# * SGD optimizer

# %% [markdown]
# ### Importing required modules
# Importing basic modules for training:
# * torch
# * datasets and transform
# * dataloader
#
# Importing Architecture:
# * Architecture
#
# Importing custom utils
# * Trainer
# * tester
# * gen_line_charts

# %%
# torch and modules
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Main architecture
from Architecture import Architecture

# custom utils and modules
from modules.trainer import Trainer
from modules.tester import test
from modules.charts import gen_line_charts

# %% [markdown]
# ## Load data
# Use datasets, transforms and DataLoader to:
# * LoadData
# * Resize image to 64x64
# * Convert to tensor
#
# For all three datasets: train, val and test

# %%
image_size = 64

transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor()
])

# make train sets
train_datasets = datasets.ImageFolder("./datasets/train", transform)
train_loader = DataLoader(
    dataset=train_datasets, 
    batch_size=32,
    num_workers=4,
    pin_memory=True,
    shuffle=True,
    persistent_workers=True
)

# make validation sets
val_datasets = datasets.ImageFolder("./datasets/val", transform)
val_loader = DataLoader(
    dataset=val_datasets, 
    batch_size=32,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True
)

# make test sets
test_datasets = datasets.ImageFolder("./datasets/test", transform)
test_loader = DataLoader(
    dataset=test_datasets, 
    batch_size=32,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True
)

# %% [markdown]
# ## Define and Use Architecture
# define a model by calling Architecture class and add layers to it:
# * 8 Convolutional Layer each followed with skipping pooling layer
# * 1 Flatten Layer followed with a 128 fully connected neural network
# * 1 Linear layer to generate 3 class logits

# %%
model = Architecture()

# %% [markdown]
# Using function to loop adding 8 convolutional layers with a skip pooling layer

# %%
def add_conv_layers(layers=1, skip_pool=0):
    # define in and out channels
    in_channels = 3
    out_channels = 8
    # size
    size = image_size
    # skip pool increase by one for calculation
    skip_pool = skip_pool+1
    # save a trainable parameters
    total_conv_params = 0
    # loop each layers to add on model
    for layer in range(layers):
        # Convolutional Layer
        model.add(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )
        # calculate trainable params
        total_conv_params += (((3*3*in_channels) + 1) * out_channels) + (2*out_channels)
        # Pooling Layer
        if  (layer + 1) % skip_pool:
            model.add(nn.MaxPool2d(2,2))
            size = size//2
        # update in and out channels
        if (layer<layers-1):
            in_channels = out_channels
            out_channels = out_channels*2
    # return total convolutional layer parameters
    return total_conv_params, out_channels, size

# %% [markdown]
# Call the `add_conv_layers()` and store parameters

# %%
conv_params, out_channels, size = add_conv_layers(8, 1)

# print conv params and out_channels
print(f"Total Trainable Parameters: {conv_params}")
print(f"Final Features: {out_channels}")
print(f"Final Feature size: {size}x{size}")
# Out:
# Total Trainable Parameters: 6297408
# Final Features: 1024
# Final Feature size: 4x4

# %% [markdown]
# use `model.add()` to add:
# * Flatten Layer (1024x4x4)
# * Hidden Layer (1024x4x4->128)
# * Output Layer (128->3)

# %%
# calculate input
n_in = out_channels*size*size
print(f"Input vector size = {n_in}")

model.add(
    # Flatten
    nn.Flatten(),
    # Hidden Layer
    nn.Linear(n_in, 128),
    nn.ReLU(),
    # Output Layer
    nn.Linear(128, 3),
    nn.ReLU()
)
# Out:
# Input vector size = 16384

# %% [markdown]
# Calculating total parameters of the model

# %%
total_trainable_parameters = ((n_in*128)+128) + ((128*3)+3)
print(f"Total trainable parameters = {total_trainable_parameters}")
# Out:
# Total trainable parameters = 2097667

# %% [markdown]
# ### Defining optimizer and Criterion
# Optimizer:
# * SGD
# * learning rate = 2e-4
# * no weight decay
#
# Critetion:
# * nn.CrossEntropy()

# %%
# optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=3e-4)
# criterion 
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train the model
# Use Trainer Function to train the complete model for 100 epochs

# %%
trainer = Trainer(
    model,
    train_loader,
    val_loader,
    optimizer,
    "cuda",
    criterion
)

# %%
save_path = "./experiments/e5_ext_e4_less_lr"

# %%
metrics = trainer.fit(100, save_path, 1)
# Out:
# EPOCH 5 completed | Training Loss = 0.8731670637628925 | Validation Loss = 0.9030150453249614
# EPOCH 10 completed | Training Loss = 0.7191875078784886 | Validation Loss = 0.8025515119234721
# EPOCH 15 completed | Training Loss = 0.6324703177409385 | Validation Loss = 0.7283640126387279
# EPOCH 20 completed | Training Loss = 0.5424265701379349 | Validation Loss = 0.6796378691991171
# EPOCH 25 completed | Training Loss = 0.47423162344676345 | Validation Loss = 0.6439365963141124
# EPOCH 30 completed | Training Loss = 0.42085525882777886 | Validation Loss = 0.6192712287108103
# EPOCH 35 completed | Training Loss = 0.3616353702634128 | Validation Loss = 0.5979075223207474
# EPOCH 40 completed | Training Loss = 0.30701262403779955 | Validation Loss = 0.582144648830096
# EPOCH 45 completed | Training Loss = 0.2754584566425921 | Validation Loss = 0.5895513494809469
# EPOCH 50 completed | Training Loss = 0.24359125332601034 | Validation Loss = 0.5663372779885928
# EPOCH 55 completed | Training Loss = 0.2020961444324522 | Validation Loss = 0.5677724952499071
# EPOCH 60 completed | Training Loss = 0.17779342474332496 | Validation Loss = 0.6419952581326167
# EPOCH 65 completed | Training Loss = 0.15555159769841095 | Validation Loss = 0.5594418764114379
# EPOCH 70 completed | Training Loss = 0.14094810043253117 | Validation Loss = 0.5978320052226385
# EPOCH 75 completed | Training Loss = 0.11851755101511728 | Validation Loss = 0.5856349170207977
# EPOCH 80 completed | Training Loss = 0.10345847065101808 | Validation Loss = 0.6015624384085337
# EPOCH 85 completed | Training Loss = 0.08308595847060431 | Validation Loss = 0.5619049211343129
# EPOCH 90 completed | Training Loss = 0.07928268044297375 | Validation Loss = 0.6020289391279221
# EPOCH 95 completed | Training Loss = 0.07345975724174016 | Validation Loss = 0.6273069580396017
# EPOCH 100 completed | Training Loss = 0.057319183903398796 | Validation Loss = 0.5821932589014371

# %% [markdown]
# ## Plot the training metrics
# Plotting line chart of training metrics that shows curves of loss, accuracy, precision, recall and f1-score for training set and validation set.

# %%
gen_line_charts(metrics, save_path, "training_metrics_graph.png", ["train_", "val_"])

# %% [markdown]
# ### Model Evaluation
# The loss curve on the training set tends to decrease smoothly approaching 0 indicating the model is learning on the traininig set. The loss curve on the validation set tends to decrease and stabalize at approximately 0.55. The curves have no extreme peaks and valleys and maintains a very smooth flow in comparison to previous experiments. A clear gap between training loss and validation loss is visible indicating possible overfittings.
#
# The accuracy, precision, recall and F1-score curve shows a similar pattern throughout the epochs. The training curve rises approximating towards 1.00. The validation curve also tends to rise approximating around 0.8. Both training and validation curves are smoothly rising without extreme fluctuations. The curves indicates the model was learning smoothly while generalizing well throughout the training. The best performing model is at epoch 98 with all metrics approximately 0.81 while the training metrics were approximately around 0.995.
#
# Overall the model is showed a slow but stable learning. Though the validation scores comparatively less than in previous experiments, this experiments shows better learning and generalizing. Overfitting is present but the model generalizes well with the validation set.

# %% [markdown]
# ## Testing the epoch 98 for making a good evaluation

# %%
tested = test(model, "./experiments/e5_ext_e4_less_lr/models/epoch_98.pt", test_loader, criterion, "cuda")

# %%
tested
# Out:
# {'test_accuracy': 0.8333333333333334,
#  'test_precision': 0.8344917582653905,
#  'test_recall': 0.8352339235556876,
#  'test_f1_score': 0.8339797179218792,
#  'test_loss': 0.4431513254841169}

# %% [markdown]
# ## Test Evaluation
# The 97th epoch shows a promising result giving 83% of accuracy, precision, recall and f1_score. The test loss is approximately 0.44. The model can be used for making the predictions. Even if the model seems to memorize the training set it still generalizes well with the validation and test sets.
